# %% [markdown]
# <a href="https://colab.research.google.com/github/martuballestrasse/01_clase/blob/main/clasen2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Encabezado
# ---
# Tasks:
#   -almacenar texto en una variable
#   -crear un array, lista

# %%
#Sumatoria hasta el numero 2_000 pero numeros impares

numeros = list(range(1, 2000, 2))
sumatoria = sum (numeros)
sumatoria
# Out:
# 1000000

# %%
import math
import random

# %%
variable_iteracion = []

for numero_rango in list(range(1, 100)):
  numero_aleatorio = random.random() * numero_rango
  variable_iteracion.append(numero_aleatorio)


variable_iteracion
# Out:
# [0.6018950734097928,
#  1.144378271628158,
#  0.5385310910939254,
#  2.2190101648197027,
#  0.2651900744919211,
#  3.237446226826256,
#  0.606505740631287,
#  6.194898630957318,
#  5.5820831435422615,
#  8.641348263955207,
#  8.999873846149804,
#  2.8033065356847517,
#  5.259355113130376,
#  11.776421515778134,
#  6.648905567953086,
#  10.802763300551916,
#  13.012515063350763,
#  0.1528803154385776,
#  5.262631453547476,
#  19.347409532044807,
#  20.148736727667824,
#  19.642523179699864,
#  11.148972537639688,
#  22.603156794420837,
#  17.53556751184555,
#  0.06613844939943281,
#  24.916100928295215,
#  26.30823650849287,
#  28.65702222147096,
#  4.198606827903454,
#  10.944435444020973,
#  24.568638194067585,
#  26.00799003089725,
#  20.108022056965165,
#  15.683985458278727,
#  16.024164381033287,
#  3.0558611169503127,
#  35.437957725747296,
#  16.804088607977267,
#  32.09442646181708,
#  3.1431784810608794,
#  34.92969058805236,
#  9.387630714440748,
#  18.427394486716334,
#  41.89738024379574,
#  35.37506489774154,
#  40.63621711606811,
#  21.496964111669932,
#  36.31769897104182,
#  44.08290144764541,
#  31.058114659476672,
#  21.113699462924835,
#  18.0354715214749,
#  9.38791018356904,
#  39.51473676512841,
#  37.85912638486767,
#  39.182035909988755,
#  2.3833846496885114,
#  57.39870964819583,
#  13.65907350205182,
#  50.64584987430587,
#  59.16983037247023,
#  51.963226970391155,
#  4.561123170175016,
#  2.8537308750216717,
#  48.56683036682802,
#  43.06334000389385,
#  17.288056443195792,
#  10.858169993161754,
#  44.10267230047044,
#  67.1951360934103,
#  15.540150389303042,
#  68.43020986826379,
#  56.89247931335475,
#  6.003207150284434,
#  33.98483875228065,
#  41.50667750234435,
#  6.213600570402351,
#  70.87428181174609,
#  28.824002312125856,
#  16.319192294743818,
#  73.75791149710562,
#  62.93243470975137,
#  50.7983551063647,
#  21.655427124715576,
#  17.73399093021096,
#  75.85629880271458,
#  71.45749206977436,
#  66.9827703662706,
#  3.713666493373935,
#  51.86554285550539,
#  26.602598673356365,
#  5.5338701994135135,
#  46.631989697555326,
#  3.441110420385119,
#  34.04104044715349,
#  47.4126581507406,
#  36.90293907059579,
#  80.57912147654193]

# %%
def breaker_printer(lista_iterable: list, tope:int) -> str:
  contador = 0
  while lista_iterable[contador] < tope:
    print(f"El numero de iteracion es: {contador} -> y su valor es\t, {lista_iterable[contador]:.3f}")
    contador += 1
  else:
    return f"Ya estoy afuera y el siguiente numero va a ser mayor a {tope}"

# %%
breaker_printer(variable_iteracion, 30)
# Out:
# El numero de iteracion es: 0 -> y su valor es	, 0.808
# El numero de iteracion es: 1 -> y su valor es	, 0.573
# El numero de iteracion es: 2 -> y su valor es	, 0.722
# El numero de iteracion es: 3 -> y su valor es	, 1.467
# El numero de iteracion es: 4 -> y su valor es	, 2.034
# El numero de iteracion es: 5 -> y su valor es	, 3.612
# El numero de iteracion es: 6 -> y su valor es	, 3.172
# El numero de iteracion es: 7 -> y su valor es	, 5.143
# El numero de iteracion es: 8 -> y su valor es	, 4.472
# El numero de iteracion es: 9 -> y su valor es	, 8.934
# El numero de iteracion es: 10 -> y su valor es	, 1.758
# El numero de iteracion es: 11 -> y su valor es	, 3.130
# El numero de iteracion es: 12 -> y su valor es	, 2.436
# El numero de iteracion es: 13 -> y su valor es	, 9.514
# El numero de iteracion es: 14 -> y su valor es	, 6.993
# El numero de iteracion es: 15 -> y su valor es	, 10.509
# El numero de iteracion es: 16 -> y su valor es	, 10.670
# El numero de iteracion es: 17 -> y su valor es	, 12.772
# El numero de iteracion es: 18 -> y su valor es	, 13.707
# El numero de iteracion es: 19 -> y su valor es	, 11.401
# El numero de iteracion es: 20 -> y su valor es	, 10.560
# El numero de iteracion es: 21 -> y su valor es	, 8.425
# El numero de iteracion es: 22 -> y su valor es	, 5.889
# El numero de iteracion es: 23 -> y su valor es	, 23.210
# El numero de iteracion es: 24 -> y su valor es	, 21.876
# El numero de iteracion es: 25 -> y su valor es	, 17.451
# El numero de iteracion es: 26 -> y su valor es	, 5.580
# El numero de iteracion es: 27 -> y su valor es	, 15.411
# El numero de iteracion es: 28 -> y su valor es	, 13.230
# El numero de iteracion es: 29 -> y su valor es	, 24.707
# El numero de iteracion es: 30 -> y su valor es	, 16.308
# El numero de iteracion es: 31 -> y su valor es	, 11.810
# El numero de iteracion es: 32 -> y su valor es	, 19.652
# El numero de iteracion es: 33 -> y su valor es	, 20.091
# El numero de iteracion es: 34 -> y su valor es	, 5.373
# El numero de iteracion es: 35 -> y su valor es	, 12.304
# 'Ya estoy afuera y el siguiente numero va a ser mayor a 30'
